# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([340,1080,640,880,990,510])
y=np.array([500,1700,1100,800,1400,500])
plt.scatter(x,y,color="red",marker='*')

m_x = np.mean(x)
m_y = np.mean(y)
n=np.size(x)

ss_xx = np.sum(x*x) - n * m_x * m_x
ss_xy = np.sum(x*y) - n * m_x * m_y

b1=ss_xy/ss_xx
b0=m_y - b1 * m_x

print(b0,b1)
y_pred=b0 + b1 * x
plt.plot(x,y_pred,color='g')

xnew=790
y_pred=b0 + b1 * xnew
plt.scatter(xnew,y_pred,color='blue')
print("The Rent for 790ft2 is %.2f"%y_pred)
# Out:
# -82.02567760342367 1.4621968616262482
# The Rent for 790ft2 is 1073.11
